# %% [markdown]
# # Implementing the Gradient Descent Algorithm
#
# In this lab, we'll implement the basic functions of the Gradient Descent algorithm to find the boundary in a small dataset. First, we'll start with some functions that will help us plot and visualize the data.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#Some helper functions for plotting and drawing lines

def plot_points(X, y):
    admitted = X[np.argwhere(y==1)]
    rejected = X[np.argwhere(y==0)]
    plt.scatter([s[0][0] for s in rejected], [s[0][1] for s in rejected], s = 25, color = 'blue', edgecolor = 'k')
    plt.scatter([s[0][0] for s in admitted], [s[0][1] for s in admitted], s = 25, color = 'red', edgecolor = 'k')

def display(m, b, color='g--'):
    plt.xlim(-0.05,1.05)
    plt.ylim(-0.05,1.05)
    x = np.arange(-10, 10, 0.1)
    plt.plot(x, m*x+b, color)

# %% [markdown]
# ## Reading and plotting the data

# %%
data = pd.read_csv('data.csv', header=None)
X = np.array(data[[0,1]])
y = np.array(data[2])
plot_points(X,y)
plt.show()

# %% [markdown]
# ## TODO: Implementing the basic functions
# Here is your turn to shine. Implement the following formulas, as explained in the text.
# - Sigmoid activation function
#
# $$\sigma(x) = \frac{1}{1+e^{-x}}$$
#
# - Output (prediction) formula
#
# $$\hat{y} = \sigma(w_1 x_1 + w_2 x_2 + b)$$
#
# - Error function
#
# $$Error(y, \hat{y}) = - y \log(\hat{y}) - (1-y) \log(1-\hat{y})$$
#
# - The function that updates the weights
#
# $$ w_i \longrightarrow w_i + \alpha (y - \hat{y}) x_i$$
#
# $$ b \longrightarrow b + \alpha (y - \hat{y})$$

# %%
# Implement the following functions

# Activation (sigmoid) function
def sigmoid(x):
    return 1/(1+np.exp(-x))

# Output (prediction) formula
def output_formula(features, weights, bias):
    return sigmoid(np.dot(features,weights)+bias)

# Error (log-loss) formula
def error_formula(y, output):
    return -np.dot(y,np.log(output)) - np.dot(1-y,np.log(1-output))

# Gradient descent step
def update_weights(x, y, weights, bias, learnrate):
    for i in range(len(weights)):
        weights[i] += learnrate*x[i]*(y-output_formula(x, weights, bias))
        bias += learnrate*(y-output_formula(x, weights, bias))
        return weights, bias

# %% [markdown]
# ## Training function
# This function will help us iterate the gradient descent algorithm through all the data, for a number of epochs. It will also plot the data, and some of the boundary lines obtained as we run the algorithm.

# %%
np.random.seed(44)

epochs = 1200
learnrate = 0.01

def train(features, targets, epochs, learnrate, graph_lines=False):
    
    errors = []
    n_records, n_features = features.shape
    last_loss = None
    weights = np.random.normal(scale=1 / n_features**.5, size=n_features)
    bias = 0
    for e in range(epochs):
        del_w = np.zeros(weights.shape)
        for x, y in zip(features, targets):
            output = output_formula(x, weights, bias)
            error = error_formula(y, output)
            weights, bias = update_weights(x, y, weights, bias, learnrate)
        
        # Printing out the log-loss error on the training set
        out = output_formula(features, weights, bias)
        loss = np.mean(error_formula(targets, out))
        errors.append(loss)
        if e % 10 == 0:
            print("\n========== Epoch", e,"==========")
            if last_loss and last_loss < loss:
                print("Train loss: ", loss, "  WARNING - Loss Increasing")
            else:
                print("Train loss: ", loss)
            last_loss = loss
            predictions = out > 0.5
            accuracy = np.mean(predictions == targets)
            print("Accuracy: ", accuracy)
        if graph_lines and e % (epochs / 100) == 0:
            display(-weights[0]/weights[1], -bias/weights[1])
            

    # Plotting the solution boundary
    plt.title("Solution boundary")
    display(-weights[0]/weights[1], -bias/weights[1], 'black')

    # Plotting the data
    plot_points(features, targets)
    plt.show()

    # Plotting the error
    plt.title("Error Plot")
    plt.xlabel('Number of epochs')
    plt.ylabel('Error')
    plt.plot(errors)
    plt.show()

# %% [markdown]
# ## Time to train the algorithm!
# When we run the function, we'll obtain the following:
# - 10 updates with the current training loss and accuracy
# - A plot of the data and some of the boundary lines obtained. The final one is in black. Notice how the lines get closer and closer to the best fit, as we go through more epochs.
# - A plot of the error function. Notice how it decreases as we go through more epochs.

# %%
train(X, y, epochs, learnrate, True)
# Out:
# ========== Epoch 0 ==========
# Train loss:  72.68973345171693
# Accuracy:  0.4
#
# ========== Epoch 10 ==========
# Train loss:  67.60033397060312
# Accuracy:  0.6
#
# ========== Epoch 20 ==========
# Train loss:  63.61145516681988
# Accuracy:  0.69
#
# ========== Epoch 30 ==========
# Train loss:  60.2116557848003
# Accuracy:  0.73
#
# ========== Epoch 40 ==========
# Train loss:  57.33201011692221
# Accuracy:  0.75
#
# ========== Epoch 50 ==========
# Train loss:  54.87726671315648
# Accuracy:  0.78
#
# ========== Epoch 60 ==========
# Train loss:  52.76923492437649
# Accuracy:  0.8
#
# ========== Epoch 70 ==========
# Train loss:  50.945512385259775
# Accuracy:  0.79
#
# ========== Epoch 80 ==========
# Train loss:  49.35643826166678
# Accuracy:  0.81
#
# ========== Epoch 90 ==========
# Train loss:  47.96241158678413
# Accuracy:  0.84
#
# ========== Epoch 100 ==========
# Train loss:  46.731711826988544
# Accuracy:  0.85
#
# ========== Epoch 110 ==========
# Train loss:  45.63878054303417
# Accuracy:  0.85
#
# ========== Epoch 120 ==========
# Train loss:  44.66288669259526
# Accuracy:  0.84
#
# ========== Epoch 130 ==========
# Train loss:  43.78709660201305
# Accuracy:  0.84
#
# ========== Epoch 140 ==========
# Train loss:  42.997480088900204
# Accuracy:  0.84
#
# ========== Epoch 150 ==========
# Train loss:  42.282497413323064
# Accuracy:  0.84
#
# ========== Epoch 160 ==========
# Train loss:  41.632524001687784
# Accuracy:  0.84
#
# ========== Epoch 170 ==========
# Train loss:  41.03948007307469
# Accuracy:  0.84
#
# ========== Epoch 180 ==========
# Train loss:  40.49654031016533
# Accuracy:  0.84
#
# ========== Epoch 190 ==========
# Train loss:  39.997904843850435
# Accuracy:  0.84
#
# ========== Epoch 200 ==========
# Train loss:  39.53861743676961
# Accuracy:  0.84
#
# ========== Epoch 210 ==========
# Train loss:  39.11442020438881
# Accuracy:  0.85
#
# ========== Epoch 220 ==========
# Train loss:  38.72163678962977
# Accuracy:  0.85
#
# ========== Epoch 230 ==========
# Train loss:  38.357077831971424
# Accuracy:  0.85
#
# ========== Epoch 240 ==========
# Train loss:  38.01796401326292
# Accuracy:  0.84
#
# ========== Epoch 250 ==========
# Train loss:  37.7018630458755
# Accuracy:  0.84
#
# ========== Epoch 260 ==========
# Train loss:  37.40663778696246
# Accuracy:  0.84
#
# ========== Epoch 270 ==========
# Train loss:  37.130403283632205
# Accuracy:  0.84
#
# ========== Epoch 280 ==========
# Train loss:  36.871491027837166
# Accuracy:  0.84
#
# ========== Epoch 290 ==========
# Train loss:  36.628419063591096
# Accuracy:  0.84
#
# ========== Epoch 300 ==========
# Train loss:  36.3998668699505
# Accuracy:  0.84
#
# ========== Epoch 310 ==========
# Train loss:  36.184654161191396
# Accuracy:  0.85
#
# ========== Epoch 320 ==========
# Train loss:  35.981722915783024
# Accuracy:  0.85
#
# ========== Epoch 330 ==========
# Train loss:  35.79012207932771
# Accuracy:  0.85
#
# ========== Epoch 340 ==========
# Train loss:  35.6089944920375
# Accuracy:  0.85
#
# ========== Epoch 350 ==========
# Train loss:  35.43756567492771
# Accuracy:  0.85
#
# ========== Epoch 360 ==========
# Train loss:  35.27513417556799
# Accuracy:  0.85
#
# ========== Epoch 370 ==========
# Train loss:  35.12106322763964
# Accuracy:  0.85
#
# ========== Epoch 380 ==========
# Train loss:  34.97477352154486
# Accuracy:  0.85
#
# ========== Epoch 390 ==========
# Train loss:  34.83573691808485
# Accuracy:  0.85
#
# ========== Epoch 400 ==========
# Train loss:  34.70347096547218
# Accuracy:  0.85
#
# ========== Epoch 410 ==========
# Train loss:  34.577534102989006
# Accuracy:  0.85
#
# ========== Epoch 420 ==========
# Train loss:  34.457521453482215
# Accuracy:  0.85
#
# ========== Epoch 430 ==========
# Train loss:  34.34306112241763
# Accuracy:  0.85
#
# ========== Epoch 440 ==========
# Train loss:  34.23381093403815
# Accuracy:  0.85
#
# ========== Epoch 450 ==========
# Train loss:  34.129455545799864
# Accuracy:  0.85
#
# ========== Epoch 460 ==========
# Train loss:  34.02970389110135
# Accuracy:  0.85
#
# ========== Epoch 470 ==========
# Train loss:  33.93428690770102
# Accuracy:  0.85
#
# ========== Epoch 480 ==========
# Train loss:  33.842955515399396
# Accuracy:  0.85
#
# ========== Epoch 490 ==========
# Train loss:  33.75547881175669
# Accuracy:  0.85
#
# ========== Epoch 500 ==========
# Train loss:  33.671642458994796
# Accuracy:  0.85
#
# ========== Epoch 510 ==========
# Train loss:  33.59124723893454
# Accuracy:  0.85
#
# ========== Epoch 520 ==========
# Train loss:  33.51410775595869
# Accuracy:  0.85
#
# ========== Epoch 530 ==========
# Train loss:  33.44005127066067
# Accuracy:  0.85
#
# ========== Epoch 540 ==========
# Train loss:  33.368916649116
# Accuracy:  0.85
#
# ========== Epoch 550 ==========
# Train loss:  33.30055341466055
# Accuracy:  0.85
#
# ========== Epoch 560 ==========
# Train loss:  33.234820890727676
# Accuracy:  0.85
#
# ========== Epoch 570 ==========
# Train loss:  33.17158742473238
# Accuracy:  0.85
#
# ========== Epoch 580 ==========
# Train loss:  33.11072968422502
# Accuracy:  0.85
#
# ========== Epoch 590 ==========
# Train loss:  33.05213201760492
# Accuracy:  0.85
#
# ========== Epoch 600 ==========
# Train loss:  32.995685872608064
# Accuracy:  0.85
#
# ========== Epoch 610 ==========
# Train loss:  32.94128926658424
# Accuracy:  0.85
#
# ========== Epoch 620 ==========
# Train loss:  32.888846303275656
# Accuracy:  0.86
#
# ========== Epoch 630 ==========
# Train loss:  32.838266731416
# Accuracy:  0.86
#
# ========== Epoch 640 ==========
# Train loss:  32.789465540998705
# Accuracy:  0.86
#
# ========== Epoch 650 ==========
# Train loss:  32.74236259352641
# Accuracy:  0.86
#
# ========== Epoch 660 ==========
# Train loss:  32.69688228296048
# Accuracy:  0.86
#
# ========== Epoch 670 ==========
# Train loss:  32.652953224444815
# Accuracy:  0.86
#
# ========== Epoch 680 ==========
# Train loss:  32.61050796819265
# Accuracy:  0.86
#
# ========== Epoch 690 ==========
# Train loss:  32.56948273620165
# Accuracy:  0.86
#
# ========== Epoch 700 ==========
# Train loss:  32.52981717970553
# Accuracy:  0.86
#
# ========== Epoch 710 ==========
# Train loss:  32.491454155487254
# Accuracy:  0.86
#
# ========== Epoch 720 ==========
# Train loss:  32.454339519369
# Accuracy:  0.86
#
# ========== Epoch 730 ==========
# Train loss:  32.41842193536432
# Accuracy:  0.86
#
# ========== Epoch 740 ==========
# Train loss:  32.3836526991276
# Accuracy:  0.86
#
# ========== Epoch 750 ==========
# Train loss:  32.349985574470566
# Accuracy:  0.86
#
# ========== Epoch 760 ==========
# Train loss:  32.31737664183476
# Accuracy:  0.86
#
# ========== Epoch 770 ==========
# Train loss:  32.28578415771497
# Accuracy:  0.86
#
# ========== Epoch 780 ==========
# Train loss:  32.25516842412438
# Accuracy:  0.86
#
# ========== Epoch 790 ==========
# Train loss:  32.22549166727704
# Accuracy:  0.87
#
# ========== Epoch 800 ==========
# Train loss:  32.19671792473966
# Accuracy:  0.87
#
# ========== Epoch 810 ==========
# Train loss:  32.16881294037291
# Accuracy:  0.87
#
# ========== Epoch 820 ==========
# Train loss:  32.14174406644446
# Accuracy:  0.87
#
# ========== Epoch 830 ==========
# Train loss:  32.1154801723508
# Accuracy:  0.87
#
# ========== Epoch 840 ==========
# Train loss:  32.08999155943489
# Accuracy:  0.87
#
# ========== Epoch 850 ==========
# Train loss:  32.0652498814317
# Accuracy:  0.87
#
# ========== Epoch 860 ==========
# Train loss:  32.04122807011409
# Accuracy:  0.87
#
# ========== Epoch 870 ==========
# Train loss:  32.017900265748175
# Accuracy:  0.87
#
# ========== Epoch 880 ==========
# Train loss:  31.99524175200048
# Accuracy:  0.87
#
# ========== Epoch 890 ==========
# Train loss:  31.973228894969246
# Accuracy:  0.87
#
# ========== Epoch 900 ==========
# Train loss:  31.951839086039342
# Accuracy:  0.87
#
# ========== Epoch 910 ==========
# Train loss:  31.931050688285172
# Accuracy:  0.87
#
# ========== Epoch 920 ==========
# Train loss:  31.9108429861682
# Accuracy:  0.87
#
# ========== Epoch 930 ==========
# Train loss:  31.891196138296106
# Accuracy:  0.87
#
# ========== Epoch 940 ==========
# Train loss:  31.87209113302959
# Accuracy:  0.87
#
# ========== Epoch 950 ==========
# Train loss:  31.853509746738965
# Accuracy:  0.87
#
# ========== Epoch 960 ==========
# Train loss:  31.835434504529186
# Accuracy:  0.87
#
# ========== Epoch 970 ==========
# Train loss:  31.81784864326505
# Accuracy:  0.87
#
# ========== Epoch 980 ==========
# Train loss:  31.80073607674185
# Accuracy:  0.87
#
# ========== Epoch 990 ==========
# Train loss:  31.784081362858302
# Accuracy:  0.87
#
# ========== Epoch 1000 ==========
# Train loss:  31.767869672659373
# Accuracy:  0.87
#
# ========== Epoch 1010 ==========
# Train loss:  31.752086761126524
# Accuracy:  0.87
#
# ========== Epoch 1020 ==========
# Train loss:  31.73671893960195
# Accuracy:  0.87
#
# ========== Epoch 1030 ==========
# Train loss:  31.721753049741746
# Accuracy:  0.87
#
# ========== Epoch 1040 ==========
# Train loss:  31.7071764389005
# Accuracy:  0.87
#
# ========== Epoch 1050 ==========
# Train loss:  31.692976936856834
# Accuracy:  0.87
#
# ========== Epoch 1060 ==========
# Train loss:  31.679142833795993
# Accuracy:  0.87
#
# ========== Epoch 1070 ==========
# Train loss:  31.665662859471396
# Accuracy:  0.87
#
# ========== Epoch 1080 ==========
# Train loss:  31.652526163472494
# Accuracy:  0.87
#
# ========== Epoch 1090 ==========
# Train loss:  31.63972229653146
# Accuracy:  0.87
#
# ========== Epoch 1100 ==========
# Train loss:  31.627241192805947
# Accuracy:  0.87
#
# ========== Epoch 1110 ==========
# Train loss:  31.615073153079177
# Accuracy:  0.87
#
# ========== Epoch 1120 ==========
# Train loss:  31.6032088288228
# Accuracy:  0.87
#
# ========== Epoch 1130 ==========
# Train loss:  31.591639207071665
# Accuracy:  0.87
#
# ========== Epoch 1140 ==========
# Train loss:  31.580355596062972
# Accuracy:  0.87
#
# ========== Epoch 1150 ==========
# Train loss:  31.569349611595232
# Accuracy:  0.87
#
# ========== Epoch 1160 ==========
# Train loss:  31.55861316406581
# Accuracy:  0.87
#
# ========== Epoch 1170 ==========
# Train loss:  31.548138446148087
# Accuracy:  0.87
#
# ========== Epoch 1180 ==========
# Train loss:  31.537917921072168
# Accuracy:  0.87
#
# ========== Epoch 1190 ==========
# Train loss:  31.52794431147484
# Accuracy:  0.87
